# %% [markdown]
# # Hyperparameter Tuning with Optuna
#
# In this notebook, we use Optuna to tune an XGBoost model for predicting hospital readmission using multiclass classification (0 = No, 1 = <30 days, 2 = >30 days).

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
import pandas as pd
from pathlib import Path

# %%
# Load the data
data_path = Path("..") / "data" / "diabetic_data.csv"
df = pd.read_csv(data_path)

# %%
y = df['readmitted_binary']
X = df.drop(columns=['readmitted_binary'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/my_ds_env/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'readmitted_binary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Assume df is already loaded and preprocessed
# ----> 2 y = df['readmitted_binary']
#       3 X = df.drop(columns=['readmitted_binary'])
#
# File ~/miniconda3/envs/my_ds_env/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/miniconda3/envs/my_ds_env/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'readmitted_binary'

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

sample_weights = y_train.map({0: 0.618, 1: 2.987, 2: 0.954})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 X_train, X_val, y_train, y_val = train_test_split(
# ----> 2     X, y, test_size=0.2, stratify=y, random_state=42
#       3 )
#       5 sample_weights = y_train.map({0: 0.618, 1: 2.987, 2: 0.954})
#
# NameError: name 'X' is not defined

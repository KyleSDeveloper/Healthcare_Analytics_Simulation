# %% [markdown]
# # XGBoost Modeling
# This notebook loads preprocessed data, trains an XGBoost model, evaluates it, and inspects feature importance.

# %%
# Reload preprocessing module after editing
import sys
from pathlib import Path

sys.path.append(str(Path("..", "src").resolve()))

import preprocessing
from importlib import reload
reload(preprocessing)

from preprocessing import load_and_preprocess_data

# %%
X, y = load_and_preprocess_data("../data/diabetic_data.csv")
# Out:
# Remaining non-numeric columns in X:
# []

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    n_estimators=260,
    learning_rate=0.0203,
    max_depth=10,
    min_child_weight=3,
    gamma=0.33,
    subsample=0.5899,
    colsample_bytree=0.5294,
    reg_alpha=0.3815,
    reg_lambda=1.5034,
    objective="multi:softprob",
    num_class=3,
    random_state=42,
    n_jobs=-1
)

sample_weights = y_train.map({0: 0.618, 1: 2.987, 2: 0.954})
model.fit(X_train, y_train, sample_weight=sample_weights)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/my_ds_env/lib/python3.12/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/miniconda3/envs/my_ds_env/lib/python3.12/site-packages/sklearn/base.py:469, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     467 output = {"text/plain": repr(self)}
#     468 if get_config()["display"] == "diagram":
# --> 469     output["text/html"] = estimator_html_repr(self)
#     470 return output
#
# File ~/miniconda3/envs/my_ds_env/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py:387, in estimator_html_repr(estimator)
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.61      0.64     10973
#            1       0.20      0.32      0.25      2272
#            2       0.46      0.44      0.45      7109
#
#     accuracy                           0.52     20354
#    macro avg       0.44      0.46      0.45     20354
# weighted avg       0.54      0.52      0.53     20354
#
# Confusion matrix:
#  [[6658 1409 2906]
#  [ 744  721  807]
#  [2547 1405 3157]]

# %%
import shap

explainer = shap.Explainer(model)
shap_values = explainer(X_train[:100])
shap.plots.beeswarm(shap_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       3 explainer = shap.Explainer(model)
#       4 shap_values = explainer(X_train[:100])
# ----> 5 shap.plots.beeswarm(shap_values)
#
# File ~/miniconda3/envs/my_ds_env/lib/python3.12/site-packages/shap/plots/_beeswarm.py:124, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     120 elif len(sv_shape) > 2:
#     121     emsg = (
#     122         "The beeswarm plot does not support plotting explanations with instances that have more than one dimension!"
#     123     )
# --> 124     raise ValueError(emsg)
#     126 if ax and plot_size:
#     127     emsg = (
#     128         "The beeswarm plot does not support passing an axis and adjusting the plot size. "
# ...
